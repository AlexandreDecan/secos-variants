# %% [markdown]
# # Variant data

# %%
import pandas
import gc

# %matplotlib inline

# %% [markdown]
# This notebook requires `data/variants.csv.gz` and, as such, needs to be executed after "Detect variants".
# Running this notebook requires at least 16Gb of memory. It should be quite easy to adapt it so that 8 Gb is enough...
#
# The goal of this notebook is to collect and extract data from the various files located in `data-raw`. These data will be a subset restricted to mainlines and variants (so the files are smaller, and can be stored and distributed in `data/`).

# %% [markdown]
# ### Load data

# %%
df_variants = pandas.read_csv(
    '../data/variants.csv.gz'
)

# %%
df_variants
# Out:
#                             mainline                           mainline_repo  \
# 0                              wheat                        creationix/wheat
# 1                              wheat                        creationix/wheat
# 2                            keypair                    juliangruber/keypair
# 3                            keypair                    juliangruber/keypair
# 4                    sasl-digest-md5          jaredhanson/js-sasl-digest-md5
# ...                              ...                                     ...
# 12808                     dot-values                 bajankristof/dot-values
# 12809                    kompression                     tuananh/kompression
# 12810  contentful-typescript-codegen  intercom/contentful-typescript-codegen
# 12811            prometheus-gc-stats         SimenB/node-prometheus-gc-stats
# 12812            jest-serializer-vue         eddyerburgh/jest-serializer-vue
#
#        mainline_repoid                                  variant  \
# 0               162291                                 11zwheat
# 1               162291                                   barley
# 2               110982                                 akeypair
# 3               110982                               jh-keypair
# 4               149511                      alt-sasl-digest-md5
# ...                ...                                      ...
# 12808         34049409                              dot-values2
# 12809         30312975                 @nivinjoseph/kompression
# 12810         39168489  @zeusdeux/contentful-typescript-codegen
# 12811         13589391                     prometheus-gc-stats2
# 12812         28366472                  jest-serializer-vue-tjw
#
#                                  variant_repo  variant_repoid
# 0                                 sun11/wheat           49882
# 1                              frodare/barley          124697
# 2                          quartzjer/akeypair           86500
# 3                         johnhaley81/keypair          805497
# 4                legastero/js-sasl-digest-md5           86665
# ...                                       ...             ...
# 12808                   bluelovers/dot-values        41256794
# 12809                 nivinjoseph/kompression        41256967
# 12810  zeusdeux/contentful-typescript-codegen        41257476
# 12811        acifani/node-prometheus-gc-stats        41257504
# 12812        tjw-lint/jest-serializer-vue-tjw        41257510
#
# [12813 rows x 6 columns]

# %%
df_packages = pandas.read_csv(
    '../data-raw/packages.csv.gz'
)

# %%
df_packages
# Out:
#                                 package       license  \
# 0                                     0  BSD-2-Clause
# 1                                   001           NaN
# 2                               001_skt           NaN
# 3                              001_test           NaN
# 4                                   007           MIT
# ...                                 ...           ...
# 1275077                urlparser-simple           MIT
# 1275078  red-contrib-samsung-tv-control           MIT
# 1275079                  ss_react_ts_ui           ISC
# 1275080                    dropdown-act           NaN
# 1275081          cra-template-ts-fabric           MIT
#
#                                                 repository      repoid
# 0                                                      NaN         NaN
# 1                                                      NaN         NaN
# 2                                                      NaN         NaN
# 3                                                      NaN         NaN
# 4                            https://github.com/btford/007     49873.0
# ...                                                    ...         ...
# 1275077                 https://github.com/dcmox/urlparser         NaN
# 1275078  https://github.com/Toxblh/node-red-contrib-sam...  41257604.0
# 1275079        https://github.com/shjyy1983/ss_react_ts_ui  41257629.0
# 1275080                                                NaN         NaN
# 1275081   https://github.com/nissan/cra-template-ts-fabric  41257632.0
#
# [1275082 rows x 4 columns]

# %%
df_releases = pandas.read_csv(
    '../data-raw/releases.csv.gz'
)

# %%
df_releases
# Out:
#                          package version                     date
# 0                              0   0.0.0  2014-04-01 22:51:11 UTC
# 1                            001   0.0.1  2014-08-08 06:02:45 UTC
# 2                        001_skt   0.0.1  2014-08-08 06:09:50 UTC
# 3                       001_test   0.0.1  2014-08-08 06:36:13 UTC
# 4                            007   0.0.0  2013-07-26 19:46:10 UTC
# ...                          ...     ...                      ...
# 11400697          ss_react_ts_ui   1.0.2  2020-01-13 01:17:56 UTC
# 11400698          ss_react_ts_ui   1.0.3  2020-01-13 01:18:23 UTC
# 11400699          ss_react_ts_ui   1.0.5  2020-01-13 01:20:46 UTC
# 11400700            dropdown-act   0.2.0  2020-01-13 01:18:07 UTC
# 11400701  cra-template-ts-fabric   1.0.0  2020-01-13 01:27:01 UTC
#
# [11400702 rows x 3 columns]

# %%
df_dependencies = pandas.read_csv(
    '../data-raw/dependencies.csv.gz'
)

# %%
df_dependencies
# Out:
#                  source version         kind                           target  \
# 0                   007   0.0.1  Development                           should
# 1                   007   0.0.1  Development                            mocha
# 2                   007   0.0.2  Development                           should
# 3                   007   0.0.2  Development                            mocha
# 4                    01   0.0.1      runtime                        commander
# ...                 ...     ...          ...                              ...
# 154471982  dropdown-act   0.2.0      runtime     @progress/kendo-react-charts
# 154471983  dropdown-act   0.2.0      runtime    @progress/kendo-react-buttons
# 154471984  dropdown-act   0.2.0      runtime  @progress/kendo-react-animation
# 154471985  dropdown-act   0.2.0      runtime          @progress/kendo-drawing
# 154471986  dropdown-act   0.2.0      runtime       @progress/kendo-data-query
#
#           constraint
# 0             ~1.2.2
# 1            ~1.12.0
# 2             ~1.2.2
# 3            ~1.12.0
# 4              1.0.x
# ...              ...
# 154471982     ^3.9.0
# 154471983     ^3.9.0
# 154471984     ^3.9.0
# 154471985     ^1.6.0
# 154471986     ^1.5.2
#
# [154471987 rows x 5 columns]

# %%
df_repositories = pandas.read_csv(
    '../data-raw/repositories.csv.gz'
)

# %%
df_repositories
# Out:
#            host                                  repository    repoid  forks  \
# 0        GitHub                   brianmhunt/knockout-modal         1      0
# 1        GitHub             SteveSanderson/knockout.mapping         2    797
# 2        GitHub                     azman-co/knockout-model         3      0
# 3        GitHub               zonuexe/aozora-ruby-parser.js         4      1
# 4        GitHub                  immense/knockout-pickatime         5      1
# ...         ...                                         ...       ...    ...
# 1209606  GitHub                sunnysingh/use-context-state  41257545      0
# 1209607  GitHub                               daywiss/utils  41257575      0
# 1209608  GitHub  Toxblh/node-red-contrib-samsung-tv-control  41257604      0
# 1209609  GitHub                    shjyy1983/ss_react_ts_ui  41257629      0
# 1209610  GitHub               nissan/cra-template-ts-fabric  41257632      0
#
#          stars  watchers  contributors     license    forked_from  \
# 0            7       2.0             1         MIT            NaN
# 1          559      62.0            21       Other            NaN
# 2            1       1.0             5         NaN  devco/knockup
# 3            3       1.0             1         NaN            NaN
# 4            1       2.0             1         MIT            NaN
# ...        ...       ...           ...         ...            ...
# 1209606      0       1.0             1         NaN            NaN
# 1209607      1       2.0             1         NaN            NaN
# 1209608      0       1.0             1         MIT            NaN
# 1209609      0       1.0             1  Apache-2.0            NaN
# 1209610      0       1.0             1         MIT            NaN
#
#                       created_at             collected_at  \
# 0        2014-09-15 01:21:34 UTC  2016-12-28 16:33:17 UTC
# 1        2010-11-01 09:27:43 UTC  2018-11-22 02:20:37 UTC
# 2        2014-09-13 03:14:07 UTC  2017-03-18 22:40:02 UTC
# 3        2014-12-27 21:02:09 UTC  2016-12-28 16:45:20 UTC
# 4        2014-12-04 21:13:48 UTC  2018-12-21 11:30:13 UTC
# ...                          ...                      ...
# 1209606  2020-01-12 23:53:51 UTC  2020-01-13 07:22:59 UTC
# 1209607  2019-12-22 18:31:00 UTC  2020-01-13 01:15:36 UTC
# 1209608  2020-01-13 00:56:01 UTC  2020-01-13 08:18:31 UTC
# 1209609  2020-01-12 05:50:09 UTC  2020-01-13 01:31:08 UTC
# 1209610  2020-01-13 01:00:47 UTC  2020-01-13 08:18:23 UTC
#
#                        last_push
# 0        2016-12-18 18:31:32 UTC
# 1        2017-06-21 22:54:45 UTC
# 2        2015-01-14 02:01:03 UTC
# 3        2015-01-07 18:04:42 UTC
# 4        2014-12-11 16:12:08 UTC
# ...                          ...
# 1209606  2020-01-12 23:54:05 UTC
# 1209607  2020-01-13 01:01:47 UTC
# 1209608  2020-01-13 01:54:36 UTC
# 1209609  2020-01-13 01:20:42 UTC
# 1209610  2020-01-13 01:28:45 UTC
#
# [1209611 rows x 12 columns]

# %%
df_repodeps = pandas.read_csv(
    '../data-raw/repo_deps.csv.gz'
)

# %%
df_repodeps
# Out:
#             host                  repository    repoid         kind  \
# 0         GitHub   brianmhunt/knockout-modal         1  development
# 1         GitHub   brianmhunt/knockout-modal         1  development
# 2         GitHub   brianmhunt/knockout-modal         1  development
# 3         GitHub   brianmhunt/knockout-modal         1  development
# 4         GitHub   brianmhunt/knockout-modal         1  development
# ...          ...                         ...       ...          ...
# 13048464  GitHub                   protzi/dm  20842311  development
# 13048465  GitHub                   protzi/dm  20842311  development
# 13048466  GitHub              elsewares/sidr  20842312  development
# 13048467  GitHub  luisvilches/luisvilches.cl  20842321      runtime
# 13048468  GitHub  luisvilches/luisvilches.cl  20842321      runtime
#
#                         target constraint
# 0                         gulp     ^3.8.8
# 1            gulp-autoprefixer     ^1.0.0
# 2                    gulp-bump    ^0.1.11
# 3                 gulp-connect     ^2.0.6
# 4                  gulp-filter     ^1.0.2
# ...                        ...        ...
# 13048464                eslint    ^3.16.0
# 13048465  eslint-config-airbnb    ^14.1.0
# 13048466                 grunt     ~0.4.0
# 13048467                   vue     ^2.1.0
# 13048468          vue-material     ^0.7.1
#
# [13048469 rows x 6 columns]

# %% [markdown]
# ### Identify packages (mainlines & variants) and their dependents

# %%
variants = df_variants['mainline'].append(df_variants['variant']).drop_duplicates()
variant_repoid = df_variants['mainline_repoid'].append(df_variants['variant_repoid']).drop_duplicates()

# %%
len(variants), len(variant_repoid)
# Out:
# (23219, 23219)

# %%
dependents = df_dependencies[lambda d: d['target'].isin(variants)]['source'].drop_duplicates()

# %%
len(dependents)
# Out:
# 345265

# %%
dependent_repo = df_repodeps[lambda d: d['target'].isin(variants)]['repoid'].drop_duplicates()

# %%
len(dependent_repo)
# Out:
# 333889

# %% [markdown]
# ### Extract data

# %%
(
    df_packages
    [lambda d: d['package'].isin(variants.append(dependents))]
    .to_csv('../data/packages.csv.gz', compression='gzip', index=False)
)

# %%
del df_packages
gc.collect()
# Out:
# 0

# %%
(
    df_releases
    [lambda d: d['package'].isin(variants.append(dependents))]
    .to_csv('../data/releases.csv.gz', compression='gzip', index=False)
)

# %%
del df_releases
gc.collect()
# Out:
# 0

# %%
(
    df_dependencies
    [lambda d: d['source'].isin(variants) | d['target'].isin(variants)]
    .to_csv('../data/dependencies.csv.gz', compression='gzip', index=False)
)

# %%
del df_dependencies
gc.collect()
# Out:
# 0

# %%
(
    df_repositories
    [lambda d: d['repoid'].isin(variant_repoid.append(dependent_repo))]
    .to_csv('../data/repositories.csv.gz', compression='gzip', index=False)
)

# %%
del df_repositories
gc.collect()
# Out:
# 0

# %%
(
    df_repodeps
    [lambda d: d['repoid'].isin(dependent_repo)]
    .to_csv('../data/repo_deps.csv.gz', compression='gzip', index=False)
)

# %%
del df_repodeps
gc.collect()
# Out:
# 0
