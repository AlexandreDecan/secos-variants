# %% [markdown]
# # Release data from npm

# %% [markdown]
# This notebook requires the file produced by `Detect variants` (i.e., "data/variants.csv.gz") and downloads the information of releases for all packages of this file using NPM registry. The initial goal is to collect license information for these releases.

# %%
import pandas
import requests
import tqdm
import logging

from time import sleep

from multiprocessing import Pool

# %%
# https://github.com/npm/registry/blob/master/docs/responses/package-metadata.md
REGISTRY = 'https://registry.npmjs.org/{package}'

# Define how to retrieve the data, since its format has changed many times
def get_version(md):
    return md['version']

def get_license(md):
    if isinstance(md.get('license', None), str):
        return md['license']
    
    # Older format, list of licenses
    licenses = []
    for item in md.get('licenses', []):
        value = item if isinstance(item, str) else item.get('type')
        if isinstance(value, str):
            licenses.append(value)
    
    # SPDX expression if more than one
    if len(licenses) > 1:
        return '(' + ' OR '.join(licenses) + ')'
    else:
        return ''.join(licenses)  # At most one item

def get_maintainers(md):
    if 'maintainers' not in md:
        return
    
    if isinstance(md['maintainers'], str):
        return md['maintainers']
    
    maintainers = []
    for item in md['maintainers']:
        if isinstance(item, str):
            maintainers.append(value)
        else:
            name = item.get('name', None)
            email = item.get('email', None)
            if name is not None and email is not None:
                maintainers.append('{} <{}>'.format(name, email))
            elif name is not None:
                maintainers.append(name)
            elif email is not None: 
                maintainers.append('<{}>'.format(email))
        
    return '; '.join(maintainers)

def get_repository(md):
    repo = md.get('repository', dict())
    if isinstance(repo, list):
        repo = repo[0]
    return repo if isinstance(repo, str) else repo.get('url', None)
    

ACCESSORS = {
    'version': get_version,
    'license': get_license,
    'maintainers': get_maintainers,
    'repository': get_repository,
}

# %% [markdown]
# ### Load data

# %%
df_variants = pandas.read_csv('../data/variants.csv.gz')

# %%
packages = df_variants['mainline'].append(df_variants['variant']).drop_duplicates()

# %% [markdown]
# Load data from existing file, if any, so we can resume the process.

# %%
columns = ['package'] + list(ACCESSORS.keys())

try:
    df_data = pandas.read_csv('../data/releases_npm.csv.gz')
    if df_data.columns != columns:
        raise ValueError()
except (FileNotFoundError, ValueError):
    df_data = pandas.DataFrame(columns=columns)

# %%
df_data
# Out:
# Empty DataFrame
# Columns: [package, version, license, maintainers, repository]
# Index: []

# %% [markdown]
# ### Retrieve data

# %%
def task(package):
    logging.info('Trying package {}'.format(package))
    
    data = []
    r = None
    
    while getattr(r, 'status_code', 429) == 429:
        r = requests.get(REGISTRY.format(package=package))
        if r.status_code == 429:
            logging.info('Retrying package {}.'.format(package))
            sleep(5)
        elif r.status_code == 200:
            for version, md in r.json().get('versions', dict()).items():
                d = {k: v(md) for k, v in ACCESSORS.items()}
                d['package'] = package
                data.append(d)
        else:
            logging.error('Package {} lead to code {}.'.format(package, r.status_code))
    
    return data

# %%
remaining = list(set(packages).difference(df_data['package']))

print('Packages:', len(packages))
print('Retrieved:', len(df_data.drop_duplicates('package')))
print('Remaining:', len(remaining))

with Pool() as pool:
    iterator = pool.imap_unordered(task, remaining, chunksize=10)
    
    for new_data in tqdm.tqdm(iterator, total=len(remaining), position=0):
        df_data = df_data.append(
            pandas.DataFrame(new_data, columns=columns)
        )
# Out:
# Packages: 23219
# Retrieved: 0
# Remaining: 23219
#   7%|▋         | 1731/23219 [01:53<15:15, 23.47it/s] ERROR:root:Package @proux/node-updown lead to code 404.
#   8%|▊         | 1961/23219 [02:07<13:23, 26.47it/s]ERROR:root:Package @dannyweapons/epy-scss lead to code 404.
#  10%|█         | 2376/23219 [02:34<20:53, 16.63it/s]ERROR:root:Package @martinreiche/gatsby-source-firestore lead to code 404.
#  15%|█▍        | 3471/23219 [03:44<20:40, 15.92it/s]ERROR:root:Package @metta/mt-v-menucircular-suspenso lead to code 404.
# ERROR:root:Package @libertyware/model-form-builder lead to code 404.
#  16%|█▌        | 3692/23219 [04:00<33:01,  9.85it/s]ERROR:root:Package @sethb0/koa-json lead to code 404.
#  20%|██        | 4653/23219 [05:03<17:00, 18.19it/s]ERROR:root:Package @eeertekin/vue-cli-plugin-tailwind lead to code 404.
#  24%|██▍       | 5521/23219 [06:05<15:48, 18.66it/s]ERROR:root:Package @zlook/vue-colorpicker lead to code 404.
#  29%|██▊       | 6641/23219 [07:20<21:57, 12.59it/s]ERROR:root:Package @studiolabs/opentok-react-native lead to code 404.
#  31%|███▏      | 7271/23219 [08:01<18:22, 14.47it/s]ERROR:root:Package @sethb0/koa-sslify lead to code 404.
#  33%|███▎      | 7635/23219 [08:30<32:12,  8.07it/s]ERROR:root:Package @metta/mt-v-menulateral lead to code 404.
#  34%|███▎      | 7784/23219 [08:39<09:13, 27.87it/s]ERROR:root:Package @gin0606/react-tree-menu lead to code 404.
#  34%|███▎      | 7822/23219 [08:43<17:41, 14.51it/s]ERROR:root:Package @plainflow/analytics.js-core lead to code 404.
#  37%|███▋      | 8511/23219 [09:29<22:23, 10.95it/s]ERROR:root:Package @tonyfg/denormalize_json_api lead to code 404.
#  40%|███▉      | 9181/23219 [10:13<18:35, 12.59it/s]ERROR:root:Package @lfdoherty/gl-texture2d-display lead to code 404.
#  46%|████▌     | 10600/23219 [11:48<10:28, 20.09it/s]ERROR:root:Package @fukaoi/bs-material-ui-ppx lead to code 404.
#  48%|████▊     | 11180/23219 [12:27<14:58, 13.40it/s]ERROR:root:Package @fourteenmeister/react-base-table lead to code 404.
#  54%|█████▍    | 12612/23219 [14:05<06:08, 28.80it/s]ERROR:root:Package @honeyscience/honey-swearjar lead to code 404.
#  57%|█████▋    | 13187/23219 [14:47<13:08, 12.72it/s]ERROR:root:Package @biggillystyle/acl-sequelize lead to code 404.
#  58%|█████▊    | 13434/23219 [15:04<16:00, 10.19it/s]ERROR:root:Package @naturalcycles/shared-dev lead to code 404.
#  58%|█████▊    | 13579/23219 [15:17<23:33,  6.82it/s]ERROR:root:Package @michaelheerklotz/svgexport lead to code 404.
#  62%|██████▏   | 14290/23219 [16:03<03:53, 38.29it/s]ERROR:root:Package @chungchiehlun/react-dropbox-chooser lead to code 404.
#  64%|██████▍   | 14864/23219 [16:44<07:33, 18.43it/s]ERROR:root:Package @bradhugh/ng8-material-keyboard-core lead to code 404.
# ERROR:root:Package @yavuzmester/degrees-radians lead to code 404.
#  64%|██████▍   | 14929/23219 [16:49<06:30, 21.21it/s]ERROR:root:Package @talaikis/react-native-aes-kit lead to code 404.
#  79%|███████▊  | 18267/23219 [20:46<04:31, 18.25it/s]ERROR:root:Package @fatfisz/grunt-touch lead to code 404.
#  79%|███████▉  | 18337/23219 [20:51<06:49, 11.91it/s]ERROR:root:Package @odeon-org/nest-mongodb lead to code 404.
#  81%|████████  | 18746/23219 [21:18<02:43, 27.40it/s]ERROR:root:Package @wadehrarshpreet/react-rater lead to code 404.
#  83%|████████▎ | 19265/23219 [21:55<04:37, 14.24it/s]ERROR:root:Package @nicodoerr/bootstrap4-tagsinput lead to code 404.
#  84%|████████▎ | 19427/23219 [22:07<04:17, 14.70it/s]ERROR:root:Package @senheng/react-pixi-fiber lead to code 404.
#  84%|████████▍ | 19509/23219 [22:12<03:18, 18.71it/s]ERROR:root:Package @tools-alive-react/react-native-animate-number lead to code 404.
#  85%|████████▍ | 19626/23219 [22:20<03:15, 18.39it/s]ERROR:root:Package @authdog/promised-ldap lead to code 404.
#  88%|████████▊ | 20467/23219 [23:18<01:42, 26.95it/s]ERROR:root:Package @metta/mt-v-menucircular-mensagens lead to code 404.
#  89%|████████▉ | 20640/23219 [23:29<01:50, 23.33it/s]ERROR:root:Package @lfdoherty/gl-shader lead to code 404.
#  89%|████████▉ | 20723/23219 [23:36<01:56, 21.39it/s]ERROR:root:Package @sethb0/koa-csrf lead to code 404.
#  90%|████████▉ | 20829/23219 [23:43<01:21, 29.20it/s]ERROR:root:Package @acadomia/datepicker lead to code 404.
#  92%|█████████▏| 21445/23219 [24:25<01:34, 18.80it/s]ERROR:root:Package @kxpvcr/ip-to-country lead to code 404.
# 100%|██████████| 23219/23219 [26:26<00:00, 14.63it/s]

# %%
(
    df_data
    .drop_duplicates()
    .to_csv('../data/releases_npm.csv.gz', compression='gzip', index=False)
)

# %%
df_data
# Out:
#                                               package version     license  \
# 0                                        fetch-cookie   0.1.0
# 1                                        fetch-cookie   0.1.1   Unlicense
# 2                                        fetch-cookie   0.1.2   Unlicense
# 3                                        fetch-cookie   0.1.3   Unlicense
# 4                                        fetch-cookie   0.1.4   Unlicense
# ..                                                ...     ...         ...
# 11                webpack-watched-glob-entries-plugin   2.1.4         MIT
# 12                webpack-watched-glob-entries-plugin   2.1.5         MIT
# 0                                @gouch/to-title-case   2.2.0         MIT
# 1                                @gouch/to-title-case   2.2.1         MIT
# 0   @meister-of-manufacturing-it/node-red-contrib-...   0.1.2  Apache-2.0
#
#                             maintainers  \
# 0    valeriangalliat <val@codejam.info>
# 1    valeriangalliat <val@codejam.info>
# 2    valeriangalliat <val@codejam.info>
# 3    valeriangalliat <val@codejam.info>
# 4    valeriangalliat <val@codejam.info>
# ..                                  ...
# 11      milanzor <milanvanas@gmail.com>
# 12      milanzor <milanvanas@gmail.com>
# 0              gouch <dgouch@gmail.com>
# 1              gouch <dgouch@gmail.com>
# 0   ryoichi-obara <npmjs0102@gmail.com>
#
#                                            repository
# 0   git+https://github.com/valeriangalliat/fetch-c...
# 1   git+https://github.com/valeriangalliat/fetch-c...
# 2   git+https://github.com/valeriangalliat/fetch-c...
# 3   git+https://github.com/valeriangalliat/fetch-c...
# 4   git+https://github.com/valeriangalliat/fetch-c...
# ..                                                ...
# 11  git+https://github.com/Milanzor/webpack-watche...
# 12  git+https://github.com/Milanzor/webpack-watche...
# 0      git+https://github.com/gouch/to-title-case.git
# 1      git+https://github.com/gouch/to-title-case.git
# 0   git+https://github.com/meister-of-manufacturin...
#
# [202286 rows x 5 columns]
